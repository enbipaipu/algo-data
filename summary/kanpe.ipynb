# %%
import networkx as nx
from collections import deque
import heapq
import random

# %% [markdown]
# ##### G.nodes() nodeのリストを取得
# ##### G.edges[u, v]['weight'] u、v間を結ぶedgeの重みを取得
# ##### nx.number_of_nodes(G) Gのノード数を取得
# ##### G.neighbors(u)  uの隣接点を取得

# %%
# Xの中に含まれる最小の点を返す
def my_extract_min(D, X):
    arg_min = -1
    min_value = float('inf')
    
    for i in range(len(D)):
        if D[i] < min_value:
            if i in X:
                arg_min = i
                min_value = D[i]
    
    return arg_min

# ダイクストラ
def my_Dijkstra(G:nx.classes.graph.Graph, s):
    X = set(G.nodes)
    D = [float('inf')] * nx.number_of_nodes(G)
    D[s] = 0

    count = 1

    while X:
        u = my_extract_min(D, X)
        X.remove(u)
        for v in G.neighbors(u):
            if v in X:
                new_distance = D[u] + G.edges[u, v]['weight']
                if D[v] > new_distance:
                    D[v] = new_distance

        print(count, " : ", D)
        count += 1
        
    return D

# %%
# 二分ヒープのダイクストラ
def my_heap_Dijkstra(G, s):
    X = set(G.nodes)
    D = [float('inf')] * nx.number_of_nodes(G) 
    D[s] = 0
    Q = []
    heapq.heappush(Q, (D[s], s))

    count = 1

    while Q:
        u_distance, u = heapq.heappop(Q)
        if D[u] < u_distance:
            continue
        X.remove(u)
        for v in G.neighbors(u):
            if v in X:
                new_distance = u_distance + G.edges[u, v]['weight']
                if D[v] > new_distance:
                    D[v] = new_distance
                    heapq.heappush(Q, (new_distance, v))

        print(count, " : ", D)
        count += 1

    return D

# %%
def my_extract_min(D, X):
    arg_min = -1
    min_value = float('inf')
    
    for i in range(len(D)):
        if D[i] < min_value:
            if i in X:
                arg_min = i
                min_value = D[i]
    
    return arg_min
# プリム法
def my_Prim(G, s):
    X = set(G.nodes)
    D = [float('inf')] * nx.number_of_nodes(G)
    D[s] = 0
    P = [-1] * nx.number_of_nodes(G)
    A = []

    count = 1

    while X:
        u = my_extract_min(D, X)
        X.remove(u)
        if u != s:
            A.append((P[u], u))
        for v in G.neighbors(u):
            if v in X:
                new_distance = G.edges[u, v]['weight']
                if D[v] > new_distance:
                    D[v] = new_distance
                    P[v] = u

        print(count, " 回目 ")
        print(D)
        print(P)
        count += 1

    return A

# %%
# ベルマンフォード法
def my_Bellman_Ford(G:nx.classes.digraph.DiGraph, s: int):
    
    n = nx.number_of_nodes(G)
    D = [float('inf')]*n
    D[s] = 0

    count = 1

    for s in range(1, n):
        D_new = D[:]
        
        for u, v in G.edges():
            new_distance = D[u] + G.edges[u, v]['weight']
            
            if D_new[v] > new_distance:
                D_new[v] = new_distance

        D = D_new
        
        print(count, "回目: ", D_new)
        
    
    for u, v in G.edges():
        new_distance = D[u] + G.edges[u, v]['weight']

        if D[v]> new_distance:
            return (False, D)
        
    return (True, D)
