# %%
import networkx as nx

# %%
G1 = nx.Graph()

for s in range(1, 10):
    G1.add_node(s)
    if s >= 2:
        G1.add_edge(s-1, s)

G1.add_edge(1, 8)
G1.add_edge(2, 8)
G1.add_edge(3, 6)
G1.add_edge(3, 9)
G1.add_edge(4, 6)
G1.add_edge(7, 9)

nx.draw(G1, with_labels = True)
